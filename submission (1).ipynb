# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("C:\\Users\\kumar\\Downloads\\Oracle of Delphi -20221211T031809Z-001\\Oracle of Delphi\\Training set.csv")

# %%
df.head(5)
# Out:
#    Unnamed: 0.1  Unnamed: 0  Monthly_Inhand_Salary   Accounts of user  \
# 0          5279        5279             4377.072500                10
# 1           473         473             2184.576667                 8
# 2          1355        1355             1837.084167                 3
# 3          1546        1546             6867.951667                 5
# 4          1323        1323             1089.858750                 4
#
#    Credit cards user have  Interest Rate  Num_of_Loan  Delay_from_due_date  \
# 0                       6             27            6                   35
# 1                       6             32            7                   51
# 2                       7              3            2                   14
# 3                       4              9            1                    6
# 4                       7              4            2                   12
#
#    Num_of_Delayed_Payment  Changed_Credit_Limit  Outstanding_Debt  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6094 entries, 0 to 6093
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0.1             6094 non-null   int64
#  1   Unnamed: 0               6094 non-null   int64
#  2   Monthly_Inhand_Salary    6094 non-null   float64
#  3   Accounts of user         6094 non-null   int64
#  4   Credit cards user have   6094 non-null   int64
#  5   Interest Rate            6094 non-null   int64
#  6   Num_of_Loan              6094 non-null   int64
#  7   Delay_from_due_date      6094 non-null   int64
#  8   Num_of_Delayed_Payment   6094 non-null   int64
#  9   Changed_Credit_Limit     6094 non-null   float64
#  10  Outstanding_Debt         6094 non-null   float64
#  11  Total_EMI_per_month      6094 non-null   float64
#  12  Amount_invested_monthly  6094 non-null   float64
#  13  Monthly_Balance          6094 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0  Monthly_Inhand_Salary   Accounts of user  \
# count   6094.000000  6094.000000             6094.000000       6094.000000
# mean    3806.815228  3806.815228             4105.351815         18.182803
# std     2193.304181  2193.304181             3110.624926        121.376021
# min        0.000000     0.000000              355.208333          0.000000
# 25%     1920.250000  1920.250000             1615.541667          4.000000
# 50%     3809.500000  3809.500000             3030.334167          6.000000
# 75%     5698.750000  5698.750000             5855.600416          8.000000
# max     7617.000000  7617.000000            14958.336670       1789.000000
#
#        Credit cards user have  Interest Rate  Num_of_Loan  \
# count             6094.000000    6094.000000  6094.000000
# mean                21.541024      65.382671     2.654578
# std                124.675409     427.394378    58.323712
# ...

# %%
df.shape
# Out:
# (6094, 19)

# %%
df.corr()
# Out:
#                          Unnamed: 0.1  Unnamed: 0  Monthly_Inhand_Salary   \
# Unnamed: 0.1                 1.000000    1.000000                0.015307
# Unnamed: 0                   1.000000    1.000000                0.015307
# Monthly_Inhand_Salary        0.015307    0.015307                1.000000
# Accounts of user            -0.010290   -0.010290               -0.031120
# Credit cards user have      -0.001031   -0.001031                0.020279
# Interest Rate               -0.013082   -0.013082               -0.002540
# Num_of_Loan                  0.000078    0.000078                0.003744
# Delay_from_due_date         -0.073679   -0.073679               -0.246409
# Num_of_Delayed_Payment      -0.017365   -0.017365               -0.019750
# Changed_Credit_Limit         0.072456    0.072456               -0.182632
# Outstanding_Debt            -0.061048   -0.061048               -0.232170
# Total_EMI_per_month          0.028441    0.028441                0.003784
# ...

# %%
df['Credit Score'].replace(['Best', 'Good','Standard'], [1,0,2], inplace=True)
df.head(100)
# Out:
#     Unnamed: 0.1  Unnamed: 0  Monthly_Inhand_Salary   Accounts of user  \
# 0           5279        5279             4377.072500                10
# 1            473         473             2184.576667                 8
# 2           1355        1355             1837.084167                 3
# 3           1546        1546             6867.951667                 5
# 4           1323        1323             1089.858750                 4
# ..           ...         ...                     ...               ...
# 95          6094        6094             6919.663333                 5
# 96          5142        5142             1479.784565                 8
# 97          3201        3201            11719.846670                 0
# 98           734         734             5751.085000                 8
# 99          2013        2013              944.531250                 9
#
#     Credit cards user have  Interest Rate  Num_of_Loan  Delay_from_due_date  \
# ...

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
#X= df.iloc[:,1:16]  # all features
#Y= df.iloc[:,-1]  # target output (Credit Score)

# %%
#credit_score= SelectKBest(score_func=chi2, k=4)
#fit= credit_score.fit(X,Y)

# %%
X= df[['Num_of_Loan', 'Cumulative Balance', 'Cash Flow']] 
Y= df[['Credit Score']]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.4,random_state=100)

# %%
y_train=np.ravel(y_train)

# %%
logreg= LogisticRegression()
logreg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=logreg.predict(X_test)
print (X_test) #test dataset
print (y_pred) #predicted values
# Out:
#       Num_of_Loan  Cumulative Balance  Cash Flow
# 1151         1047                3610       4448
# 828             3                2447       2982
# 2285         -100                3086       4883
# 2348            4                4213       2165
# 4531            4                4516       4159
# ...           ...                 ...        ...
# 1982            4                4797       2822
# 570             3                4384       4667
# 5741            4                1494       4416
# 4337            4                2209       2820
# 5823            3                2398       3896
#
# [2438 rows x 3 columns]
# [1 1 1 ... 1 1 1]

# %%
from sklearn import metrics
from sklearn.metrics import classification_report
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  0.6513535684987695
